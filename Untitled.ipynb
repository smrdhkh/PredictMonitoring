# %%
import pandas as pd
data=pd.read_csv("ship_it_data.csv")
data.head(10)
# Out:
#          Time  envoy_server_live  envoy_server_uptime  \
# 0  1544004060                  1                85443
# 1  1544004120                  1                85503
# 2  1544004180                  1                85563
# 3  1544004240                  1                85618
# 4  1544004300                  1                85618
# 5  1544004360                  1                85753
# 6  1544004420                  1                85813
# 7  1544004480                  1                85873
# 8  1544004540                  1                85933
# 9  1544004600                  1                85993
#
#    envoy_http_downstream_rq_total  envoy_http_rq_total  \
# 0                             379                  379
# 1                             403                  403
# 2                             427                  427
# 3                             449                  449
# 4                             449                  449
# ...

# %%
data.dtypes
# Out:
# Time                                  int64
# envoy_server_live                     int64
# envoy_server_uptime                   int64
# envoy_http_downstream_rq_total        int64
# envoy_http_rq_total                   int64
# envoy_http_rs_too_large               int64
# jvm_threads_current                   int64
# jvm_memory_bytes_used                 int64
# ugbu_chassis_resources_cpu_usage    float64
# dtype: object

# %%
data.describe()
# Out:
#                Time  envoy_server_live  envoy_server_uptime  \
# count  1.216000e+03             1216.0          1216.000000
# mean   1.544041e+09                1.0        119576.337993
# std    2.107191e+04                0.0         25247.882929
# min    1.544004e+09                1.0            75.000000
# 25%    1.544022e+09                1.0        102601.000000
# 50%    1.544041e+09                1.0        120823.000000
# 75%    1.544059e+09                1.0        139051.000000
# max    1.544077e+09                1.0        157274.000000
#
#        envoy_http_downstream_rq_total  envoy_http_rq_total  \
# count                     1216.000000          1216.000000
# mean                     14490.524671         14490.524671
# std                       8425.567481          8425.567481
# min                          3.000000             3.000000
# 25%                       7199.000000          7199.000000
# 50%                      14489.000000         14489.000000
# ...

# %%
data.tail(20)
# Out:
#             Time  envoy_server_live  envoy_server_uptime  \
# 1196  1544075820                  1               157214
# 1197  1544075880                  1               157274
# 1198  1544076000                  1                   75
# 1199  1544076060                  1                  135
# 1200  1544076120                  1                  195
# 1201  1544076180                  1                  255
# 1202  1544076240                  1                  315
# 1203  1544076300                  1                  375
# 1204  1544076360                  1                  435
# 1205  1544076420                  1                  495
# 1206  1544076480                  1                  555
# 1207  1544076540                  1                  615
# 1208  1544076600                  1                  675
# 1209  1544076660                  1                  735
# 1210  1544076720                  1                  795
# ...

# %%
corr_val=data.corr(method='pearson')
print(corr_val)
# Out:
#                                       Time  envoy_server_live  \
# Time                              1.000000                NaN
# envoy_server_live                      NaN                NaN
# envoy_server_uptime               0.676902                NaN
# envoy_http_downstream_rq_total    0.912897                NaN
# envoy_http_rq_total               0.912897                NaN
# envoy_http_rs_too_large                NaN                NaN
# jvm_threads_current              -0.204509                NaN
# jvm_memory_bytes_used             0.007835                NaN
# ugbu_chassis_resources_cpu_usage  0.035720                NaN
#
#                                   envoy_server_uptime  \
# Time                                         0.676902
# envoy_server_live                                 NaN
# envoy_server_uptime                          1.000000
# envoy_http_downstream_rq_total               0.918399
# envoy_http_rq_total                          0.918399
# ...

# %%
train=data
train.drop(['envoy_http_rs_too_large'],axis=1,inplace=True)

# %%
train.head(5)
# Out:
#          Time  envoy_server_live  envoy_server_uptime  \
# 0  1544004060                  1                85443
# 1  1544004120                  1                85503
# 2  1544004180                  1                85563
# 3  1544004240                  1                85618
# 4  1544004300                  1                85618
#
#    envoy_http_downstream_rq_total  envoy_http_rq_total  jvm_threads_current  \
# 0                             379                  379                   36
# 1                             403                  403                   36
# 2                             427                  427                   36
# 3                             449                  449                   36
# 4                             449                  449                   36
#
#    jvm_memory_bytes_used  ugbu_chassis_resources_cpu_usage
# 0               35578336                          0.002521
# 1               43207040                          0.005356
# ...

# %%
train.drop(['envoy_http_downstream_rq_total'],axis=1,inplace=True)

# %%
train.head(5)
# Out:
#          Time  envoy_server_live  envoy_server_uptime  envoy_http_rq_total  \
# 0  1544004060                  1                85443                  379
# 1  1544004120                  1                85503                  403
# 2  1544004180                  1                85563                  427
# 3  1544004240                  1                85618                  449
# 4  1544004300                  1                85618                  449
#
#    jvm_threads_current  jvm_memory_bytes_used  \
# 0                   36               35578336
# 1                   36               43207040
# 2                   36               35470136
# 3                   36               42478088
# 4                   36               42478088
#
#    ugbu_chassis_resources_cpu_usage
# 0                          0.002521
# 1                          0.005356
# 2                          0.010789
# 3                          0.002678
# 4                          0.002678

# %%
train.to_csv("Data_modified.csv",index=False)

# %%
# %matplotlib inline
def correlation_matrix(df):
    from matplotlib import pyplot as plt
    from matplotlib import cm as cm

    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    cmap = cm.get_cmap('jet', 30)
    cax = ax1.imshow(df.corr(), interpolation="nearest", cmap=cmap)
    ax1.grid(True)
    plt.title('Correlation in Data ')
    labels=['Time','envoy_server_live','envoy_server_uptime','envoy_http_rq_total','jvm_threads_current','jvm_memory_bytes_used','ugbu_chassis_resources_cpu_usage',]
    ax1.set_xticklabels(labels,fontsize=6)
    ax1.set_yticklabels(labels,fontsize=6)
    fig.colorbar(cax)
    plt.show()

# %%
df=train[0:1215]
correlation_matrix(df)

# %%
train.drop(['envoy_server_uptime'],axis=1,inplace=True)

# %%
train.head()
# Out:
#          Time  envoy_server_live  envoy_http_rq_total  jvm_threads_current  \
# 0  1544004060                  1                  379                   36
# 1  1544004120                  1                  403                   36
# 2  1544004180                  1                  427                   36
# 3  1544004240                  1                  449                   36
# 4  1544004300                  1                  449                   36
#
#    jvm_memory_bytes_used  ugbu_chassis_resources_cpu_usage
# 0               35578336                          0.002521
# 1               43207040                          0.005356
# 2               35470136                          0.010789
# 3               42478088                          0.002678
# 4               42478088                          0.002678

# %%
train.to_csv("Data_modified.csv",index=False)

# %%
# %matplotlib inline
def correlation_matrix(df):
    from matplotlib import pyplot as plt
    from matplotlib import cm as cm

    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    cmap = cm.get_cmap('jet', 30)
    cax = ax1.imshow(df.corr(), interpolation="nearest", cmap=cmap)
    ax1.grid(True)
    plt.title('Correlation in Data ')
    labels=['Time','envoy_server_live','envoy_http_rq_total','jvm_threads_current','jvm_memory_bytes_used','ugbu_chassis_resources_cpu_usage',]
    ax1.set_xticklabels(labels,fontsize=6)
    ax1.set_yticklabels(labels,fontsize=6)
    fig.colorbar(cax)
    plt.show()

# %%
df=train[0:1215]
correlation_matrix(df)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(train)
plt.show()
# Out:
# C:\Users\abhinjha\Anaconda2\lib\site-packages\matplotlib\axes\_base.py:3152: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=1.0, right=1.0
#   'left=%s, right=%s') % (left, right))
# C:\Users\abhinjha\Anaconda2\lib\site-packages\matplotlib\axes\_base.py:3471: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=1.0, top=1.0
#   'bottom=%s, top=%s') % (bottom, top))

# %%
from sklearn.preprocessing import Normalizer
ac_data=train.values;
X=ac_data[:,0:5]
Y=ac_data[:,5]
scaler=Normalizer()
rescaledx=scaler.fit_transform(X)
print(rescaledx)
# Out:
# [[9.99734618e-01 6.47494812e-10 2.45400534e-07 2.33098132e-08
#   2.30367880e-02]
#  [9.99608684e-01 6.47413223e-10 2.60907529e-07 2.33068760e-08
#   2.79728090e-02]
#  [9.99736229e-01 6.47495805e-10 2.76480709e-07 2.33098490e-08
#   2.29667643e-02]
#  ...
#  [9.99619827e-01 6.47389924e-10 2.35002542e-07 2.26586473e-08
#   2.75717413e-02]
#  [9.99739173e-01 6.47467192e-10 2.50569803e-07 2.26613517e-08
#   2.28382449e-02]
#  [9.99612246e-01 6.47384964e-10 2.66075220e-07 2.26584737e-08
#   2.78452392e-02]]

# %%
train_corr_val=train.corr(method='pearson')
print(train_corr_val)
# Out:
#                                       Time  envoy_server_live  \
# Time                              1.000000                NaN
# envoy_server_live                      NaN                NaN
# envoy_http_rq_total               0.912897                NaN
# jvm_threads_current              -0.204509                NaN
# jvm_memory_bytes_used             0.007835                NaN
# ugbu_chassis_resources_cpu_usage  0.035720                NaN
#
#                                   envoy_http_rq_total  jvm_threads_current  \
# Time                                         0.912897            -0.204509
# envoy_server_live                                 NaN                  NaN
# envoy_http_rq_total                          1.000000             0.203240
# jvm_threads_current                          0.203240             1.000000
# jvm_memory_bytes_used                        0.028014             0.048101
# ugbu_chassis_resources_cpu_usage             0.004764            -0.081786
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

x1, y1 = make_classification(n_samples=700, n_features=3,n_informative=2, n_redundant=0,random_state=0, shuffle=True)
clf = RandomForestClassifier(n_estimators=100, max_depth=2,random_state=0)
# Out:
# C:\Users\abhinjha\Anaconda2\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
clf.fit(x1, y1)
RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',max_depth=2, max_features='auto', max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,min_samples_leaf=1, min_samples_split=2,
            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,oob_score=False, random_state=0, verbose=0, warm_start=False)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=2, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
print(clf.feature_importances_)
# Out:
# [0.12512111 0.6503835  0.22449539]

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
rfe=RFE(model,3)
tlearn=rfe.fit(x1,y1)

print(tlearn.support_)
print(tlearn.ranking_)
# Out:
# [ True  True  True]
# [1 1 1]

# %%
print("Observation: - \n These are the fields impacting the output most.\n 1. envoy_http_rq_total \n 2. jvm_threads_current \n 3.jvm_memory_bytes_used  ")
# Out:
# Observation: -
#  These are the fields impacting the output most.
#  1. envoy_http_rq_total
#  2. jvm_threads_current
#  3.jvm_memory_bytes_used

# %%
print("Impact Factors are 12.512%, 65.038 % and 22.449% respectiv ")
